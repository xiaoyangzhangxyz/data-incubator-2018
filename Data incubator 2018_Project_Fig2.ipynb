# %%
import pandas as pd

# %%
St_cpb_le=pd.read_csv('project_pic2_data')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lmplot(x='Life_Expectation', y='amoxicillin_claim_per_bene', data=St_cpb_le)

# %%
plt.show()
